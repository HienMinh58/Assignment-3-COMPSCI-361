# %% [markdown]
# # COMPSCI 361 Assignment 3: BBC News Classification

# %% [markdown]
# ## Task 1: Exploratory Data Analysis

# %% [markdown]
# ## Task 2: Model Implementation
#
# - Naive Bayes
# - k-nearest neighbours
# - Support vector machine
# - Artificial neural network

# %% [markdown]
# ## Task 3: Hyperparameter Evaluation and F1 Comparison

# %% [markdown]
# ## Task 4: Final Discussion and Conclusion
